# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import pycountry_convert as pc
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('./transformed_data.csv')
df.dropna()
df
# Out:
#       CODE      COUNTRY        DATE    HDI        TC        TD       STI  \
# 0      AFG  Afghanistan  2019-12-31  0.498  0.000000  0.000000  0.000000
# 1      AFG  Afghanistan  2020-01-01  0.498  0.000000  0.000000  0.000000
# 2      AFG  Afghanistan  2020-01-02  0.498  0.000000  0.000000  0.000000
# 3      AFG  Afghanistan  2020-01-03  0.498  0.000000  0.000000  0.000000
# 4      AFG  Afghanistan  2020-01-04  0.498  0.000000  0.000000  0.000000
# ...    ...          ...         ...    ...       ...       ...       ...
# 50413  ZWE     Zimbabwe  2020-10-15  0.535  8.994048  5.442418  4.341855
# 50414  ZWE     Zimbabwe  2020-10-16  0.535  8.996528  5.442418  4.341855
# 50415  ZWE     Zimbabwe  2020-10-17  0.535  8.999496  5.442418  4.341855
# 50416  ZWE     Zimbabwe  2020-10-18  0.535  9.000853  5.442418  4.341855
# 50417  ZWE     Zimbabwe  2020-10-19  0.535  9.005405  5.442418  4.341855
#
#              POP    GDPCAP
# 0      17.477233  7.497754
# 1      17.477233  7.497754
# 2      17.477233  7.497754
# 3      17.477233  7.497754
# 4      17.477233  7.497754
# ...          ...       ...
# 50413  16.514381  7.549491
# 50414  16.514381  7.549491
# 50415  16.514381  7.549491
# 50416  16.514381  7.549491
# 50417  16.514381  7.549491
#
# [50418 rows x 9 columns]

# %%
df.describe()
# Out:
#                 HDI            TC            TD           STI           POP  \
# count  44216.000000  50418.000000  50418.000000  50418.000000  50418.000000
# mean       0.720139      6.762125      3.413681      3.178897     15.442097
# std        0.160902      3.637347      3.082761      1.673451      2.495039
# min        0.000000      0.000000      0.000000      0.000000      6.695799
# 25%        0.601000      4.158883      0.000000      2.867331     14.151619
# 50%        0.752000      7.092574      3.178054      4.000583     15.929201
# 75%        0.847000      9.504669      5.620401      4.335852     17.187513
# max        0.953000     15.914092     12.299900      4.605170     21.087439
#
#              GDPCAP
# count  50418.000000
# mean       8.318580
# std        3.177130
# min        0.000000
# 25%        7.955479
# 50%        9.368531
# 75%       10.237704
# max       11.669379

# %%
df = df[(df[['HDI', 'TC', 'TD', 'STI', 'GDPCAP']] != 0).all(axis=1)]
df.describe()
# Out:
#                 HDI            TC            TD           STI           POP  \
# count  29007.000000  29809.000000  29809.000000  29809.000000  29809.000000
# mean       0.726251      8.864973      5.117971      4.093640     16.332341
# std        0.155843      2.374951      2.540207      0.414866      1.763213
# min        0.354000      0.693147      0.693147      1.022451     10.432291
# 25%        0.608000      7.170888      3.218876      3.893248     15.412430
# 50%        0.754000      8.834046      4.828314      4.220390     16.265620
# 75%        0.853000     10.648397      6.776507      4.389002     17.477233
# max        0.953000     15.864821     12.277328      4.605170     21.087439
#
#              GDPCAP
# count  29809.000000
# mean       9.390271
# std        1.203052
# min        6.494117
# 25%        8.554484
# 50%        9.588836
# 75%       10.392249
# max       11.669379

# %%
df.isnull().sum()
# Out:
# CODE         0
# COUNTRY      0
# DATE         0
# HDI        802
# TC           0
# TD           0
# STI          0
# POP          0
# GDPCAP       0
# dtype: int64

# %%
df.interpolate(method='linear', inplace=True)
# Out:
# C:\Users\andid\AppData\Local\Temp\ipykernel_16428\2868764835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.interpolate(method='linear', inplace=True)

# %%
df.isnull().sum()
# Out:
# CODE       0
# COUNTRY    0
# DATE       0
# HDI        0
# TC         0
# TD         0
# STI        0
# POP        0
# GDPCAP     0
# dtype: int64

# %%
country = df.drop_duplicates(subset=['CODE'], keep='last')

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 279 to 50417
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CODE     155 non-null    object
#  1   COUNTRY  155 non-null    object
#  2   DATE     155 non-null    object
#  3   HDI      155 non-null    float64
#  4   TC       155 non-null    float64
#  5   TD       155 non-null    float64
#  6   STI      155 non-null    float64
#  7   POP      155 non-null    float64
#  8   GDPCAP   155 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 12.1+ KB

# %%
country = country.reset_index()
country.drop('index', inplace=True, axis=1)
country
# Out:
#     CODE      COUNTRY        DATE    HDI         TC         TD       STI  \
# 0    AFG  Afghanistan  2020-10-05  0.498  10.580023   7.287561  3.218876
# 1    ALB      Albania  2020-10-05  0.785   9.565634   5.981414  3.773221
# 2    DZA      Algeria  2020-10-12  0.754  10.879405   7.496097  4.329812
# 3    AGO       Angola  2020-10-08  0.581   8.652598   5.327876  4.266896
# 4    ARG    Argentina  2020-10-09  0.825  13.660441  10.030561  4.476882
# ..   ...          ...         ...    ...        ...        ...       ...
# 150  VEN    Venezuela  2020-10-15  0.761  11.350465   6.570883  4.476882
# 151  VNM      Vietnam  2020-10-19  0.694   7.033506   3.555348  3.948355
# 152  YEM        Yemen  2020-10-12  0.452   7.628031   6.390241  3.814851
# 153  ZMB       Zambia  2020-10-05  0.588   9.619266   5.808142  3.794140
# 154  ZWE     Zimbabwe  2020-10-19  0.535   9.005405   5.442418  4.341855
#
#            POP    GDPCAP
# 0    17.477233  7.497754
# 1    14.872537  9.376146
# 2    17.596309  9.540639
# 3    17.307957  8.668969
# 4    17.626514  9.848710
# ..         ...       ...
# 150  17.163165  9.725856
# 151  18.393706  8.727759
# 152  17.210890  7.299221
# 153  16.726989  8.213179
# 154  16.514381  7.549491
#
# [155 rows x 9 columns]

# %%
country.drop(['DATE', 'COUNTRY'], inplace=True, axis=1)
country
# Out:
#     CODE    HDI         TC         TD       STI        POP    GDPCAP
# 0    AFG  0.498  10.580023   7.287561  3.218876  17.477233  7.497754
# 1    ALB  0.785   9.565634   5.981414  3.773221  14.872537  9.376146
# 2    DZA  0.754  10.879405   7.496097  4.329812  17.596309  9.540639
# 3    AGO  0.581   8.652598   5.327876  4.266896  17.307957  8.668969
# 4    ARG  0.825  13.660441  10.030561  4.476882  17.626514  9.848710
# ..   ...    ...        ...        ...       ...        ...       ...
# 150  VEN  0.761  11.350465   6.570883  4.476882  17.163165  9.725856
# 151  VNM  0.694   7.033506   3.555348  3.948355  18.393706  8.727759
# 152  YEM  0.452   7.628031   6.390241  3.814851  17.210890  7.299221
# 153  ZMB  0.588   9.619266   5.808142  3.794140  16.726989  8.213179
# 154  ZWE  0.535   9.005405   5.442418  4.341855  16.514381  7.549491
#
# [155 rows x 7 columns]

# %% [markdown]
# ### EDA

# %%
country.hist(column=['HDI', 'TC', 'TD', 'STI', 'GDPCAP'], figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'HDI'}>, <Axes: title={'center': 'TC'}>],
#        [<Axes: title={'center': 'TD'}>, <Axes: title={'center': 'STI'}>],
#        [<Axes: title={'center': 'GDPCAP'}>, <Axes: >]], dtype=object)

# %%
corr = country[['HDI', 'TC', 'TD', 'STI', 'POP', 'GDPCAP']].corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
country_code = country['CODE'].unique().tolist()
alpha2_code = []
for i in country_code:
    alpha2_code.append(pc.country_alpha3_to_country_alpha2(i))
continent_code = []
for i in alpha2_code:
    try:
        continent_code.append(pc.country_alpha2_to_continent_code(i))
    except:
        continent_code.append('Unknown')
        
country['CONTINENT'] = continent_code
country
# Out:
#     CODE    HDI         TC         TD       STI        POP    GDPCAP CONTINENT
# 0    AFG  0.498  10.580023   7.287561  3.218876  17.477233  7.497754        AS
# 1    ALB  0.785   9.565634   5.981414  3.773221  14.872537  9.376146        EU
# 2    DZA  0.754  10.879405   7.496097  4.329812  17.596309  9.540639        AF
# 3    AGO  0.581   8.652598   5.327876  4.266896  17.307957  8.668969        AF
# 4    ARG  0.825  13.660441  10.030561  4.476882  17.626514  9.848710        SA
# ..   ...    ...        ...        ...       ...        ...       ...       ...
# 150  VEN  0.761  11.350465   6.570883  4.476882  17.163165  9.725856        SA
# 151  VNM  0.694   7.033506   3.555348  3.948355  18.393706  8.727759        AS
# 152  YEM  0.452   7.628031   6.390241  3.814851  17.210890  7.299221        AS
# 153  ZMB  0.588   9.619266   5.808142  3.794140  16.726989  8.213179        AF
# 154  ZWE  0.535   9.005405   5.442418  4.341855  16.514381  7.549491        AF
#
# [155 rows x 8 columns]

# %%
country.drop(['TD', 'STI'], inplace=True, axis=1)

# %%
continent = country.groupby(by="CONTINENT").size()
continent
# Out:
# CONTINENT
# AF    46
# AS    38
# EU    37
# NA    18
# OC     4
# SA    12
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data=country, x_vars=['HDI', 'TC', 'POP'], y_vars=['GDPCAP'], height=5, aspect=0.75)
plt.show()

# %%
sns.catplot(data=country, x='CONTINENT', y='GDPCAP', kind='box')
plt.title('Boxplot of GDP per Capita by Continent')
plt.figure(figsize=(10,8))

# %%
sns.scatterplot(data=country, x='HDI', y='GDPCAP', hue='CONTINENT')
plt.title('Scatterplot of GDP per Capita by HDI')
# Out:
# Text(0.5, 1.0, 'Scatterplot of GDP per Capita by HDI')

# %%
continent_mapping = {'AS':1,
                    'EU':2,
                    'NA':3,
                    'OC':4,
                    'SA':5,
                    'AF':6}
country['CONTINENT'] = country['CONTINENT'].map(continent_mapping)
country
# Out:
#     CODE    HDI         TC        POP    GDPCAP  CONTINENT
# 0    AFG  0.498  10.580023  17.477233  7.497754          1
# 1    ALB  0.785   9.565634  14.872537  9.376146          2
# 2    DZA  0.754  10.879405  17.596309  9.540639          6
# 3    AGO  0.581   8.652598  17.307957  8.668969          6
# 4    ARG  0.825  13.660441  17.626514  9.848710          5
# ..   ...    ...        ...        ...       ...        ...
# 150  VEN  0.761  11.350465  17.163165  9.725856          5
# 151  VNM  0.694   7.033506  18.393706  8.727759          1
# 152  YEM  0.452   7.628031  17.210890  7.299221          1
# 153  ZMB  0.588   9.619266  16.726989  8.213179          6
# 154  ZWE  0.535   9.005405  16.514381  7.549491          6
#
# [155 rows x 6 columns]

# %%
# Select the features (independent variables) and target variable (dependent variable)
X = country[['HDI', 'TC', 'POP', 'CONTINENT']]
y = country['GDPCAP']

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a Linear Regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred = model.predict(X_test)

# Model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the model evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('R-squared (R2) Score:', r2)
# Out:
# Mean Squared Error (MSE): 0.12875457931203763
# R-squared (R2) Score: 0.9000423126259273

# %%
# Create a table comparing actual GDPCAP vs predicted GDPCAP
comparison_df = pd.DataFrame({'Actual GDPCAP': y_test, 'Predicted GDPCAP': y_pred})
print(comparison_df)
# Out:
#      Actual GDPCAP  Predicted GDPCAP
# 81        9.791522          9.288816
# 142      10.131791          9.747995
# 31        9.492126          9.520274
# 29       10.033069         10.240015
# 118      10.948373         10.557284
# 60        8.421078          8.652041
# 93        7.035359          7.246641
# 147      10.900906         10.680322
# 153       8.213179          8.353377
# 68       10.408265         10.696015
# 42        9.266904          9.574139
# 138       9.697550          9.363475
# 78        9.500587          9.642956
# 75       11.090272         10.019339
# 15        7.632515          7.815239
# 19        9.668232          9.373016
# 30        9.636177          9.221017
# 90        9.760568          9.630333
# 117       7.525215          7.896183
# 137       7.894804          7.806206
# 18        9.368531          9.753946
# 12        9.750801          9.985531
# 9        10.675693         10.375177
# 24        8.121161          8.114088
# 69       10.469372         10.402579
# 131       8.404362          7.685078
# 95        9.163438          8.906230
# 45       10.291510         10.471324
# 86       10.196462          9.804809
# 84        7.255902          7.844547
# 126       9.416938          9.165982
# 96        7.800902          8.270644
# 122       7.237275          7.174851
# 82       10.292968         10.342333
# 109       9.412195          9.570595
# 65        9.856533          9.811594
# 51        7.353573          7.565097
# 26        8.735936          9.049817
# 133       8.954025          8.527441
# 76        8.129609          9.047400
# 56        8.912447          8.842822
# 36       10.386381         10.475198
# 124      10.314111         10.309419
# 22        9.828942         10.009187
# 55       10.109460         10.368532
# 85        6.998548          7.544614
# 11        9.739678         10.000187

# %%
# Create a scatter plot of actual vs. predicted values
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.xlabel('Actual GDPCAP')
plt.ylabel('Predicted GDPCAP')
plt.title('Linear Regression: Actual vs. Predicted GDPCAP')
plt.show()

# %%
import csv

# Data yang sudah dibersihkan
cleaned_data = [country.columns.to_list()] + country.values.tolist()

# Nama file .csv yang baru
new_file_path = './df_country.csv'

# Menulis data ke dalam file .csv baru
with open(new_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(cleaned_data)

print(f"File {new_file_path} berhasil dibuat.")
# Out:
# File ./df_country.csv berhasil dibuat.
